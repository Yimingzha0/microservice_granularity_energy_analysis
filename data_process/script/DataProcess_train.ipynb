# %%
import os
import csv
from datetime import datetime

# Paths
log_file_path_coarse = '../../result_f/train/coarse/cleaned_powerstat_20240729_160103.txt'
log_file_path_med = '../../result_f/train/med/cleaned_powerstat_20240729_124507.txt'
log_file_path_fine = '../../result_f/train/fine/cleaned_powerstat_20240729_092632.txt'
csv_folder_path_coarse = '../train_f/coarse/'
csv_folder_path_med = '../train_f/med/'
csv_folder_path_fine = '../train_f/fine/'


def parse_log_timestamp(log_timestamp):
    return datetime.strptime(log_timestamp, '%H:%M:%S').time()
def parse_csv_timestamp(csv_timestamp):
    return datetime.strptime(csv_timestamp.split(',')[0], '%Y-%m-%d %H:%M:%S').time()

log_entries_coarse = []
log_entries_med = []
log_entries_fine = []

with open(log_file_path_coarse, 'r') as log_file:
    for line in log_file:
        parts = line.strip().split()
        timestamp = parse_log_timestamp(parts[0])
        last_value = float(parts[-1])
        log_entries_coarse.append((timestamp, last_value))

with open(log_file_path_med, 'r') as log_file:
    for line in log_file:
        parts = line.strip().split()
        timestamp = parse_log_timestamp(parts[0])
        last_value = float(parts[-1])
        log_entries_med.append((timestamp, last_value))

with open(log_file_path_fine, 'r') as log_file:
    for line in log_file:
        parts = line.strip().split()
        timestamp = parse_log_timestamp(parts[0])
        last_value = float(parts[-1])
        log_entries_fine.append((timestamp, last_value))

results_coarse = []
results_med = []
results_fine = []

for csv_file_name in os.listdir(csv_folder_path_coarse):
    if csv_file_name.endswith('.csv'):
        csv_file_path = os.path.join(csv_folder_path_coarse, csv_file_name)

        with open(csv_file_path, 'r') as csv_file:
            csv_reader = csv.reader(csv_file)
            headers = next(csv_reader)
            first_csv_timestamp_str = next(csv_reader)[0]
            first_csv_timestamp = parse_csv_timestamp(first_csv_timestamp_str)
            log_index = -1
            for i, (log_timestamp, _) in enumerate(log_entries_coarse):
                if log_timestamp >= first_csv_timestamp:
                    log_index = i
                    break
            if log_index == -1:
                results_coarse.append((first_csv_timestamp_str, csv_file_name, None, None))
                continue
            sum_last_values = 0.0
            for i in range(log_index, min(log_index + 12, len(log_entries_coarse))):
                sum_last_values += log_entries_coarse[i][1]
            results_coarse.append((first_csv_timestamp_str, csv_file_name, log_entries_coarse[log_index][0], sum_last_values))

for csv_file_name in os.listdir(csv_folder_path_med):
    if csv_file_name.endswith('.csv'):
        csv_file_path = os.path.join(csv_folder_path_med, csv_file_name)

        with open(csv_file_path, 'r') as csv_file:
            csv_reader = csv.reader(csv_file)
            headers = next(csv_reader)
            first_csv_timestamp_str = next(csv_reader)[0]
            first_csv_timestamp = parse_csv_timestamp(first_csv_timestamp_str)
            log_index = -1
            for i, (log_timestamp, _) in enumerate(log_entries_med):
                if log_timestamp >= first_csv_timestamp:
                    log_index = i
                    break
            if log_index == -1:
                results_med.append((first_csv_timestamp_str, csv_file_name, None, None))
                continue
            sum_last_values = 0.0
            for i in range(log_index, min(log_index + 12, len(log_entries_med))):
                sum_last_values += log_entries_med[i][1]
            results_med.append((first_csv_timestamp_str, csv_file_name, log_entries_med[log_index][0], sum_last_values))

for csv_file_name in os.listdir(csv_folder_path_fine):
    if csv_file_name.endswith('.csv'):
        csv_file_path = os.path.join(csv_folder_path_fine, csv_file_name)

        with open(csv_file_path, 'r') as csv_file:
            csv_reader = csv.reader(csv_file)
            headers = next(csv_reader)
            first_csv_timestamp_str = next(csv_reader)[0]
            first_csv_timestamp = parse_csv_timestamp(first_csv_timestamp_str)
            log_index = -1
            for i, (log_timestamp, _) in enumerate(log_entries_fine):
                if log_timestamp >= first_csv_timestamp:
                    log_index = i
                    break
            if log_index == -1:
                results_fine.append((first_csv_timestamp_str, csv_file_name, None, None))
                continue
            sum_last_values = 0.0
            for i in range(log_index, min(log_index + 12, len(log_entries_fine))):
                sum_last_values += log_entries_fine[i][1]
            results_fine.append((first_csv_timestamp_str, csv_file_name, log_entries_fine[log_index][0], sum_last_values))

results_coarse.sort(key=lambda x: parse_csv_timestamp(x[0]))
results_med.sort(key=lambda x: parse_csv_timestamp(x[0]))
results_fine.sort(key=lambda x: parse_csv_timestamp(x[0]))

for csv_timestamp, csv_file_name, log_timestamp, sum_last_values in results_coarse:
    if log_timestamp is None:
        print(f"For CSV file '{csv_file_name}': No valid log entry found.")
    else:
        print(f"For CSV file '{csv_file_name}':")
        print(f"  Corresponding log timestamp: {log_timestamp}")
        print(f"  Sum of last values: {sum_last_values}")
for i in range(len(results_coarse)):
    results_coarse[i] = (results_coarse[i][0], results_coarse[i][1], results_coarse[i][2], results_coarse[i][3] * 10)
for i in range(len(results_med)):
    results_med[i] = (results_med[i][0], results_med[i][1], results_med[i][2], results_med[i][3] * 10)
for i in range(len(results_fine)):
    results_fine[i] = (results_fine[i][0], results_fine[i][1], results_fine[i][2], results_fine[i][3] * 10)

print("---------------------------MED-----------------------------------")
for csv_timestamp, csv_file_name, log_timestamp, sum_last_values in results_med:
    if log_timestamp is None:
        print(f"For CSV file '{csv_file_name}': No valid log entry found.")
    else:
        print(f"For CSV file '{csv_file_name}':")
        print(f"  Corresponding log timestamp: {log_timestamp}")
        print(f"  Sum of last values: {sum_last_values}")

print("----------------------------FINE--------------------------------")
for csv_timestamp, csv_file_name, log_timestamp, sum_last_values in results_fine:
    if log_timestamp is None:
        print(f"For CSV file '{csv_file_name}': No valid log entry found.")
    else:
        print(f"For CSV file '{csv_file_name}':")
        print(f"  Corresponding log timestamp: {log_timestamp}")
        print(f"  Sum of last values: {sum_last_values}")
# Out:
# For CSV file 'locustfile_burst_high_0.01_80_40_10s_1_requests.csv':
#   Corresponding log timestamp: 16:30:03
#   Sum of last values: 395.67999999999995
# For CSV file 'locustfile_burst_high_0.01_80_40_10s_2_requests.csv':
#   Corresponding log timestamp: 16:32:33
#   Sum of last values: 390.7
# For CSV file 'locustfile_burst_high_0.01_80_40_10s_3_requests.csv':
#   Corresponding log timestamp: 16:35:03
#   Sum of last values: 371.4200000000001
# For CSV file 'locustfile_burst_high_0.01_80_40_10s_4_requests.csv':
#   Corresponding log timestamp: 16:37:33
#   Sum of last values: 363.28999999999996
# For CSV file 'locustfile_burst_high_0.01_80_40_10s_5_requests.csv':
#   Corresponding log timestamp: 16:40:03
#   Sum of last values: 376.11
# For CSV file 'locustfile_burst_high_0.01_80_40_10s_6_requests.csv':
#   Corresponding log timestamp: 16:42:43
#   Sum of last values: 362.73
# For CSV file 'locustfile_burst_high_0.01_80_40_10s_7_requests.csv':
#   Corresponding log timestamp: 16:45:13
#   Sum of last values: 361.3299999999999
# For CSV file 'locustfile_burst_high_0.01_80_40_10s_8_requests.csv':
#   Corresponding log timestamp: 16:47:43
#   Sum of last values: 354.2800000000001
# For CSV file 'locustfile_burst_high_0.01_80_40_10s_9_requests.csv':
#   Corresponding log timestamp: 16:50:13
#   Sum of last values: 355.5899999999999
# For CSV file 'locustfile_burst_high_0.01_80_40_10s_10_requests.csv':
#   Corresponding log timestamp: 16:52:43
#   Sum of last values: 352.43000000000006
# For CSV file 'locustfile_burst_med_0.4_80_40_10s_1_requests.csv':
#   Corresponding log timestamp: 16:55:03
#   Sum of last values: 339.44999999999993
# For CSV file 'locustfile_burst_med_0.4_80_40_10s_2_requests.csv':
#   Corresponding log timestamp: 16:57:33
#   Sum of last values: 337.43000000000006
# For CSV file 'locustfile_burst_med_0.4_80_40_10s_3_requests.csv':
#   Corresponding log timestamp: 17:00:03
#   Sum of last values: 337.93999999999994
# For CSV file 'locustfile_burst_med_0.4_80_40_10s_4_requests.csv':
#   Corresponding log timestamp: 17:02:33
#   Sum of last values: 336.9200000000001
# For CSV file 'locustfile_burst_med_0.4_80_40_10s_5_requests.csv':
#   Corresponding log timestamp: 17:05:13
#   Sum of last values: 338.44
# For CSV file 'locustfile_burst_med_0.4_80_40_10s_6_requests.csv':
#   Corresponding log timestamp: 17:07:43
#   Sum of last values: 336.96
# For CSV file 'locustfile_burst_med_0.4_80_40_10s_7_requests.csv':
#   Corresponding log timestamp: 17:10:13
#   Sum of last values: 339.91999999999996
# For CSV file 'locustfile_burst_med_0.4_80_40_10s_8_requests.csv':
#   Corresponding log timestamp: 17:12:43
#   Sum of last values: 333.80999999999995
# For CSV file 'locustfile_burst_med_0.4_80_40_10s_9_requests.csv':
#   Corresponding log timestamp: 17:15:13
#   Sum of last values: 340.36999999999995
# For CSV file 'locustfile_burst_med_0.4_80_40_10s_10_requests.csv':
#   Corresponding log timestamp: 17:17:43
#   Sum of last values: 341.26
# For CSV file 'locustfile_burst_low_5_80_40_10s_1_requests.csv':
#   Corresponding log timestamp: 17:20:03
#   Sum of last values: 335.53999999999996
# For CSV file 'locustfile_burst_low_5_80_40_10s_2_requests.csv':
#   Corresponding log timestamp: 17:22:33
#   Sum of last values: 339.90000000000003
# For CSV file 'locustfile_burst_low_5_80_40_10s_3_requests.csv':
#   Corresponding log timestamp: 17:25:03
#   Sum of last values: 336.81
# For CSV file 'locustfile_burst_low_5_80_40_10s_4_requests.csv':
#   Corresponding log timestamp: 17:27:43
#   Sum of last values: 335.86999999999995
# For CSV file 'locustfile_burst_low_5_80_40_10s_5_requests.csv':
#   Corresponding log timestamp: 17:30:13
#   Sum of last values: 331.64
# For CSV file 'locustfile_burst_low_5_80_40_10s_6_requests.csv':
#   Corresponding log timestamp: 17:32:43
#   Sum of last values: 333.63999999999993
# For CSV file 'locustfile_burst_low_5_80_40_10s_7_requests.csv':
#   Corresponding log timestamp: 17:35:13
#   Sum of last values: 337.5
# For CSV file 'locustfile_burst_low_5_80_40_10s_8_requests.csv':
#   Corresponding log timestamp: 17:37:43
#   Sum of last values: 333.2800000000001
# For CSV file 'locustfile_burst_low_5_80_40_10s_9_requests.csv':
#   Corresponding log timestamp: 17:40:13
#   Sum of last values: 330.72999999999996
# For CSV file 'locustfile_burst_low_5_80_40_10s_10_requests.csv':
#   Corresponding log timestamp: 17:42:43
#   Sum of last values: 331.32
# For CSV file 'locustfile_even_high_0.5_80_40_120s_1_requests.csv':
#   Corresponding log timestamp: 17:45:03
#   Sum of last values: 374.7800000000001
# For CSV file 'locustfile_even_high_0.5_80_40_120s_2_requests.csv':
#   Corresponding log timestamp: 17:47:43
#   Sum of last values: 392.8
# For CSV file 'locustfile_even_high_0.5_80_40_120s_3_requests.csv':
#   Corresponding log timestamp: 17:50:13
#   Sum of last values: 383.61999999999995
# For CSV file 'locustfile_even_high_0.5_80_40_120s_4_requests.csv':
#   Corresponding log timestamp: 17:52:43
#   Sum of last values: 377.61999999999995
# For CSV file 'locustfile_even_high_0.5_80_40_120s_5_requests.csv':
#   Corresponding log timestamp: 17:55:13
#   Sum of last values: 376.64
# For CSV file 'locustfile_even_high_0.5_80_40_120s_6_requests.csv':
#   Corresponding log timestamp: 17:57:43
#   Sum of last values: 373.48999999999995
# For CSV file 'locustfile_even_high_0.5_80_40_120s_7_requests.csv':
#   Corresponding log timestamp: 18:00:13
#   Sum of last values: 372.39000000000004
# For CSV file 'locustfile_even_high_0.5_80_40_120s_8_requests.csv':
#   Corresponding log timestamp: 18:02:43
#   Sum of last values: 371.65
# For CSV file 'locustfile_even_high_0.5_80_40_120s_9_requests.csv':
#   Corresponding log timestamp: 18:05:13
#   Sum of last values: 370.54
# For CSV file 'locustfile_even_high_0.5_80_40_120s_10_requests.csv':
#   Corresponding log timestamp: 18:07:43
#   Sum of last values: 368.12
# For CSV file 'locustfile_even_med_6_80_40_120s_1_requests.csv':
#   Corresponding log timestamp: 18:10:13
#   Sum of last values: 336.84000000000003
# For CSV file 'locustfile_even_med_6_80_40_120s_2_requests.csv':
#   Corresponding log timestamp: 18:12:43
#   Sum of last values: 333.27
# For CSV file 'locustfile_even_med_6_80_40_120s_3_requests.csv':
#   Corresponding log timestamp: 18:15:13
#   Sum of last values: 335.84000000000003
# For CSV file 'locustfile_even_med_6_80_40_120s_4_requests.csv':
#   Corresponding log timestamp: 18:17:43
#   Sum of last values: 337.90000000000003
# For CSV file 'locustfile_even_med_6_80_40_120s_5_requests.csv':
#   Corresponding log timestamp: 18:20:13
#   Sum of last values: 342.22
# For CSV file 'locustfile_even_med_6_80_40_120s_6_requests.csv':
#   Corresponding log timestamp: 18:22:43
#   Sum of last values: 342.42
# For CSV file 'locustfile_even_med_6_80_40_120s_7_requests.csv':
#   Corresponding log timestamp: 18:25:13
#   Sum of last values: 339.76000000000005
# For CSV file 'locustfile_even_med_6_80_40_120s_8_requests.csv':
#   Corresponding log timestamp: 18:27:43
#   Sum of last values: 337.59000000000003
# For CSV file 'locustfile_even_med_6_80_40_120s_9_requests.csv':
#   Corresponding log timestamp: 18:30:13
#   Sum of last values: 339.46000000000004
# For CSV file 'locustfile_even_med_6_80_40_120s_10_requests.csv':
#   Corresponding log timestamp: 18:32:53
#   Sum of last values: 341.9699999999999
# For CSV file 'locustfile_even_low60_80_40_120s_1_requests.csv':
#   Corresponding log timestamp: 18:35:13
#   Sum of last values: 331.39
# For CSV file 'locustfile_even_low60_80_40_120s_2_requests.csv':
#   Corresponding log timestamp: 18:37:43
#   Sum of last values: 330.2999999999999
# For CSV file 'locustfile_even_low60_80_40_120s_3_requests.csv':
#   Corresponding log timestamp: 18:40:13
#   Sum of last values: 332.92
# For CSV file 'locustfile_even_low60_80_40_120s_4_requests.csv':
#   Corresponding log timestamp: 18:42:43
#   Sum of last values: 336.23999999999995
# For CSV file 'locustfile_even_low60_80_40_120s_5_requests.csv':
#   Corresponding log timestamp: 18:45:13
#   Sum of last values: 336.65000000000003
# For CSV file 'locustfile_even_low60_80_40_120s_6_requests.csv':
#   Corresponding log timestamp: 18:47:43
#   Sum of last values: 335.51000000000005
# For CSV file 'locustfile_even_low60_80_40_120s_7_requests.csv':
#   Corresponding log timestamp: 18:50:13
#   Sum of last values: 336.3
# For CSV file 'locustfile_even_low60_80_40_120s_8_requests.csv':
#   Corresponding log timestamp: 18:52:43
#   Sum of last values: 340.30000000000007
# For CSV file 'locustfile_even_low60_80_40_120s_9_requests.csv':
#   Corresponding log timestamp: 18:55:23
#   Sum of last values: 332.3
# For CSV file 'locustfile_even_low60_80_40_120s_10_requests.csv':
#   Corresponding log timestamp: 18:57:53
#   Sum of last values: 331.08
# ---------------------------MED-----------------------------------
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_1_requests.csv':
#   Corresponding log timestamp: 13:14:27
#   Sum of last values: 4208.3
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_2_requests.csv':
#   Corresponding log timestamp: 13:16:57
#   Sum of last values: 4072.800000000001
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_3_requests.csv':
#   Corresponding log timestamp: 13:19:27
#   Sum of last values: 4055.3
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_4_requests.csv':
#   Corresponding log timestamp: 13:21:57
#   Sum of last values: 3868.2
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_5_requests.csv':
#   Corresponding log timestamp: 13:24:27
#   Sum of last values: 3892.3999999999996
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_6_requests.csv':
#   Corresponding log timestamp: 13:26:57
#   Sum of last values: 3874.6
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_7_requests.csv':
#   Corresponding log timestamp: 13:29:27
#   Sum of last values: 3822.7999999999997
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_8_requests.csv':
#   Corresponding log timestamp: 13:31:57
#   Sum of last values: 3952.2999999999997
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_9_requests.csv':
#   Corresponding log timestamp: 13:34:37
#   Sum of last values: 3774.7000000000003
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_10_requests.csv':
#   Corresponding log timestamp: 13:37:07
#   Sum of last values: 3853.8999999999996
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_1_requests.csv':
#   Corresponding log timestamp: 13:39:27
#   Sum of last values: 3557.0
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_2_requests.csv':
#   Corresponding log timestamp: 13:41:57
#   Sum of last values: 3578.2
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_3_requests.csv':
#   Corresponding log timestamp: 13:44:27
#   Sum of last values: 3565.7999999999997
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_4_requests.csv':
#   Corresponding log timestamp: 13:46:57
#   Sum of last values: 3519.9999999999995
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_5_requests.csv':
#   Corresponding log timestamp: 13:49:27
#   Sum of last values: 3511.7000000000003
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_6_requests.csv':
#   Corresponding log timestamp: 13:51:57
#   Sum of last values: 3515.5
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_7_requests.csv':
#   Corresponding log timestamp: 13:54:27
#   Sum of last values: 3569.6000000000004
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_8_requests.csv':
#   Corresponding log timestamp: 13:57:07
#   Sum of last values: 3490.0
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_9_requests.csv':
#   Corresponding log timestamp: 13:59:37
#   Sum of last values: 3520.2999999999997
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_10_requests.csv':
#   Corresponding log timestamp: 14:02:07
#   Sum of last values: 3467.9999999999995
# For CSV file 'locustfile_burst_low_5_120_40_10s_1_requests.csv':
#   Corresponding log timestamp: 14:04:27
#   Sum of last values: 3459.3
# For CSV file 'locustfile_burst_low_5_120_40_10s_2_requests.csv':
#   Corresponding log timestamp: 14:06:57
#   Sum of last values: 3530.0
# For CSV file 'locustfile_burst_low_5_120_40_10s_3_requests.csv':
#   Corresponding log timestamp: 14:09:27
#   Sum of last values: 3479.6000000000004
# For CSV file 'locustfile_burst_low_5_120_40_10s_4_requests.csv':
#   Corresponding log timestamp: 14:11:57
#   Sum of last values: 3449.2000000000007
# For CSV file 'locustfile_burst_low_5_120_40_10s_5_requests.csv':
#   Corresponding log timestamp: 14:14:27
#   Sum of last values: 3527.7999999999997
# For CSV file 'locustfile_burst_low_5_120_40_10s_6_requests.csv':
#   Corresponding log timestamp: 14:17:07
#   Sum of last values: 3493.7
# For CSV file 'locustfile_burst_low_5_120_40_10s_7_requests.csv':
#   Corresponding log timestamp: 14:19:37
#   Sum of last values: 3539.1000000000004
# For CSV file 'locustfile_burst_low_5_120_40_10s_8_requests.csv':
#   Corresponding log timestamp: 14:22:07
#   Sum of last values: 3512.4
# For CSV file 'locustfile_burst_low_5_120_40_10s_9_requests.csv':
#   Corresponding log timestamp: 14:24:37
#   Sum of last values: 3494.6000000000004
# For CSV file 'locustfile_burst_low_5_120_40_10s_10_requests.csv':
#   Corresponding log timestamp: 14:27:07
#   Sum of last values: 3472.4999999999995
# For CSV file 'locustfile_even_high_0.5_120_40_120s_1_requests.csv':
#   Corresponding log timestamp: 14:29:27
#   Sum of last values: 4178.400000000001
# For CSV file 'locustfile_even_high_0.5_120_40_120s_2_requests.csv':
#   Corresponding log timestamp: 14:31:57
#   Sum of last values: 4045.7999999999993
# For CSV file 'locustfile_even_high_0.5_120_40_120s_3_requests.csv':
#   Corresponding log timestamp: 14:34:27
#   Sum of last values: 3871.8
# For CSV file 'locustfile_even_high_0.5_120_40_120s_4_requests.csv':
#   Corresponding log timestamp: 14:36:57
#   Sum of last values: 3924.6000000000004
# For CSV file 'locustfile_even_high_0.5_120_40_120s_5_requests.csv':
#   Corresponding log timestamp: 14:39:37
#   Sum of last values: 3821.399999999999
# For CSV file 'locustfile_even_high_0.5_120_40_120s_6_requests.csv':
#   Corresponding log timestamp: 14:42:07
#   Sum of last values: 3788.1
# For CSV file 'locustfile_even_high_0.5_120_40_120s_7_requests.csv':
#   Corresponding log timestamp: 14:44:37
#   Sum of last values: 3846.7999999999993
# For CSV file 'locustfile_even_high_0.5_120_40_120s_8_requests.csv':
#   Corresponding log timestamp: 14:47:07
#   Sum of last values: 3848.7999999999993
# For CSV file 'locustfile_even_high_0.5_120_40_120s_9_requests.csv':
#   Corresponding log timestamp: 14:49:37
#   Sum of last values: 3752.9999999999995
# For CSV file 'locustfile_even_high_0.5_120_40_120s_10_requests.csv':
#   Corresponding log timestamp: 14:52:07
#   Sum of last values: 3817.5
# For CSV file 'locustfile_even_med_6_120_40_120s_1_requests.csv':
#   Corresponding log timestamp: 14:54:27
#   Sum of last values: 3523.4999999999995
# For CSV file 'locustfile_even_med_6_120_40_120s_2_requests.csv':
#   Corresponding log timestamp: 14:56:57
#   Sum of last values: 3569.2000000000007
# For CSV file 'locustfile_even_med_6_120_40_120s_3_requests.csv':
#   Corresponding log timestamp: 14:59:27
#   Sum of last values: 3464.5
# For CSV file 'locustfile_even_med_6_120_40_120s_4_requests.csv':
#   Corresponding log timestamp: 15:02:07
#   Sum of last values: 3482.2999999999997
# For CSV file 'locustfile_even_med_6_120_40_120s_5_requests.csv':
#   Corresponding log timestamp: 15:04:37
#   Sum of last values: 3498.7
# For CSV file 'locustfile_even_med_6_120_40_120s_6_requests.csv':
#   Corresponding log timestamp: 15:07:07
#   Sum of last values: 3550.4999999999995
# For CSV file 'locustfile_even_med_6_120_40_120s_7_requests.csv':
#   Corresponding log timestamp: 15:09:37
#   Sum of last values: 3564.3
# For CSV file 'locustfile_even_med_6_120_40_120s_8_requests.csv':
#   Corresponding log timestamp: 15:12:07
#   Sum of last values: 3557.2999999999997
# For CSV file 'locustfile_even_med_6_120_40_120s_9_requests.csv':
#   Corresponding log timestamp: 15:14:37
#   Sum of last values: 3509.0999999999995
# For CSV file 'locustfile_even_med_6_120_40_120s_10_requests.csv':
#   Corresponding log timestamp: 15:17:07
#   Sum of last values: 3501.7
# For CSV file 'locustfile_even_low_60_120_40_120s_1_requests.csv':
#   Corresponding log timestamp: 15:19:27
#   Sum of last values: 3496.3
# For CSV file 'locustfile_even_low_60_120_40_120s_2_requests.csv':
#   Corresponding log timestamp: 15:21:57
#   Sum of last values: 3405.0
# For CSV file 'locustfile_even_low_60_120_40_120s_3_requests.csv':
#   Corresponding log timestamp: 15:24:37
#   Sum of last values: 3449.5
# For CSV file 'locustfile_even_low_60_120_40_120s_4_requests.csv':
#   Corresponding log timestamp: 15:27:07
#   Sum of last values: 3454.9999999999995
# For CSV file 'locustfile_even_low_60_120_40_120s_5_requests.csv':
#   Corresponding log timestamp: 15:29:37
#   Sum of last values: 3403.0999999999995
# For CSV file 'locustfile_even_low_60_120_40_120s_6_requests.csv':
#   Corresponding log timestamp: 15:32:07
#   Sum of last values: 3434.2
# For CSV file 'locustfile_even_low_60_120_40_120s_7_requests.csv':
#   Corresponding log timestamp: 15:34:37
#   Sum of last values: 3462.8999999999996
# For CSV file 'locustfile_even_low_60_120_40_120s_8_requests.csv':
#   Corresponding log timestamp: 15:37:07
#   Sum of last values: 3506.2
# For CSV file 'locustfile_even_low_60_120_40_120s_9_requests.csv':
#   Corresponding log timestamp: 15:39:37
#   Sum of last values: 3535.2000000000003
# For CSV file 'locustfile_even_low_60_120_40_120s_10_requests.csv':
#   Corresponding log timestamp: 15:42:07
#   Sum of last values: 3476.3999999999996
# ----------------------------FINE--------------------------------
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_1_requests.csv':
#   Corresponding log timestamp: 09:26:42
#   Sum of last values: 3640.2999999999997
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_2_requests.csv':
#   Corresponding log timestamp: 09:58:02
#   Sum of last values: 4303.8
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_3_requests.csv':
#   Corresponding log timestamp: 10:00:32
#   Sum of last values: 4282.4
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_4_requests.csv':
#   Corresponding log timestamp: 10:03:02
#   Sum of last values: 4318.200000000001
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_5_requests.csv':
#   Corresponding log timestamp: 10:05:32
#   Sum of last values: 4317.4
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_6_requests.csv':
#   Corresponding log timestamp: 10:08:02
#   Sum of last values: 4287.2
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_7_requests.csv':
#   Corresponding log timestamp: 10:10:32
#   Sum of last values: 4094.7000000000003
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_8_requests.csv':
#   Corresponding log timestamp: 10:13:12
#   Sum of last values: 4091.8
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_9_requests.csv':
#   Corresponding log timestamp: 10:15:42
#   Sum of last values: 3997.4999999999995
# For CSV file 'locustfile_burst_high_0.01_120_40_10s_10_requests.csv':
#   Corresponding log timestamp: 10:18:12
#   Sum of last values: 4184.6
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_1_requests.csv':
#   Corresponding log timestamp: 10:20:32
#   Sum of last values: 3873.899999999999
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_2_requests.csv':
#   Corresponding log timestamp: 10:23:02
#   Sum of last values: 3771.8
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_3_requests.csv':
#   Corresponding log timestamp: 10:25:32
#   Sum of last values: 3703.6000000000004
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_4_requests.csv':
#   Corresponding log timestamp: 10:28:02
#   Sum of last values: 3705.1999999999994
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_5_requests.csv':
#   Corresponding log timestamp: 10:30:32
#   Sum of last values: 3747.3999999999996
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_6_requests.csv':
#   Corresponding log timestamp: 10:33:02
#   Sum of last values: 3754.8999999999996
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_7_requests.csv':
#   Corresponding log timestamp: 10:35:42
#   Sum of last values: 3709.7999999999997
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_8_requests.csv':
#   Corresponding log timestamp: 10:38:12
#   Sum of last values: 3743.899999999999
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_9_requests.csv':
#   Corresponding log timestamp: 10:40:42
#   Sum of last values: 3639.3999999999996
# For CSV file 'locustfile_burst_med_0.4_120_40_10s_10_requests.csv':
#   Corresponding log timestamp: 10:43:12
#   Sum of last values: 3656.0
# For CSV file 'locustfile_burst_low_5_120_40_10s_1_requests.csv':
#   Corresponding log timestamp: 10:45:32
#   Sum of last values: 3804.9000000000005
# For CSV file 'locustfile_burst_low_5_120_40_10s_2_requests.csv':
#   Corresponding log timestamp: 10:48:02
#   Sum of last values: 3728.8999999999996
# For CSV file 'locustfile_burst_low_5_120_40_10s_3_requests.csv':
#   Corresponding log timestamp: 10:50:32
#   Sum of last values: 3661.2000000000007
# For CSV file 'locustfile_burst_low_5_120_40_10s_4_requests.csv':
#   Corresponding log timestamp: 10:53:02
#   Sum of last values: 3684.0
# For CSV file 'locustfile_burst_low_5_120_40_10s_5_requests.csv':
#   Corresponding log timestamp: 10:55:42
#   Sum of last values: 3655.2999999999997
# For CSV file 'locustfile_burst_low_5_120_40_10s_6_requests.csv':
#   Corresponding log timestamp: 10:58:12
#   Sum of last values: 3717.9000000000005
# For CSV file 'locustfile_burst_low_5_120_40_10s_7_requests.csv':
#   Corresponding log timestamp: 11:00:42
#   Sum of last values: 3676.2
# For CSV file 'locustfile_burst_low_5_120_40_10s_8_requests.csv':
#   Corresponding log timestamp: 11:03:12
#   Sum of last values: 3692.9
# For CSV file 'locustfile_burst_low_5_120_40_10s_9_requests.csv':
#   Corresponding log timestamp: 11:05:42
#   Sum of last values: 3679.7999999999997
# For CSV file 'locustfile_burst_low_5_120_40_10s_10_requests.csv':
#   Corresponding log timestamp: 11:08:12
#   Sum of last values: 3683.8
# For CSV file 'locustfile_even_high_0.5_120_40_120s_1_requests.csv':
#   Corresponding log timestamp: 11:10:32
#   Sum of last values: 3904.9
# For CSV file 'locustfile_even_high_0.5_120_40_120s_2_requests.csv':
#   Corresponding log timestamp: 11:13:02
#   Sum of last values: 4064.0000000000005
# For CSV file 'locustfile_even_high_0.5_120_40_120s_3_requests.csv':
#   Corresponding log timestamp: 11:15:32
#   Sum of last values: 4229.200000000001
# For CSV file 'locustfile_even_high_0.5_120_40_120s_4_requests.csv':
#   Corresponding log timestamp: 11:18:12
#   Sum of last values: 4043.2999999999993
# For CSV file 'locustfile_even_high_0.5_120_40_120s_5_requests.csv':
#   Corresponding log timestamp: 11:20:42
#   Sum of last values: 4027.9999999999995
# For CSV file 'locustfile_even_high_0.5_120_40_120s_6_requests.csv':
#   Corresponding log timestamp: 11:23:12
#   Sum of last values: 4003.4999999999995
# For CSV file 'locustfile_even_high_0.5_120_40_120s_7_requests.csv':
#   Corresponding log timestamp: 11:25:42
#   Sum of last values: 4080.999999999999
# For CSV file 'locustfile_even_high_0.5_120_40_120s_8_requests.csv':
#   Corresponding log timestamp: 11:28:12
#   Sum of last values: 3990.6
# For CSV file 'locustfile_even_high_0.5_120_40_120s_9_requests.csv':
#   Corresponding log timestamp: 11:30:42
#   Sum of last values: 4009.2000000000003
# For CSV file 'locustfile_even_high_0.5_120_40_120s_10_requests.csv':
#   Corresponding log timestamp: 11:33:12
#   Sum of last values: 3965.4999999999995
# For CSV file 'locustfile_even_med_6_120_40_120s_1_requests.csv':
#   Corresponding log timestamp: 11:35:32
#   Sum of last values: 3669.2000000000007
# For CSV file 'locustfile_even_med_6_120_40_120s_2_requests.csv':
#   Corresponding log timestamp: 11:38:02
#   Sum of last values: 3704.8
# For CSV file 'locustfile_even_med_6_120_40_120s_3_requests.csv':
#   Corresponding log timestamp: 11:40:42
#   Sum of last values: 3703.1000000000004
# For CSV file 'locustfile_even_med_6_120_40_120s_4_requests.csv':
#   Corresponding log timestamp: 11:43:12
#   Sum of last values: 3750.2
# For CSV file 'locustfile_even_med_6_120_40_120s_5_requests.csv':
#   Corresponding log timestamp: 11:45:42
#   Sum of last values: 3748.1
# For CSV file 'locustfile_even_med_6_120_40_120s_6_requests.csv':
#   Corresponding log timestamp: 11:48:12
#   Sum of last values: 3705.7999999999997
# For CSV file 'locustfile_even_med_6_120_40_120s_7_requests.csv':
#   Corresponding log timestamp: 11:50:42
#   Sum of last values: 3719.2
# For CSV file 'locustfile_even_med_6_120_40_120s_8_requests.csv':
#   Corresponding log timestamp: 11:53:12
#   Sum of last values: 3616.5
# For CSV file 'locustfile_even_med_6_120_40_120s_9_requests.csv':
#   Corresponding log timestamp: 11:55:42
#   Sum of last values: 3666.5
# For CSV file 'locustfile_even_med_6_120_40_120s_10_requests.csv':
#   Corresponding log timestamp: 11:58:12
#   Sum of last values: 3741.600000000001
# For CSV file 'locustfile_even_low_60_120_40_120s_1_requests.csv':
#   Corresponding log timestamp: 12:00:32
#   Sum of last values: 3649.7000000000003
# For CSV file 'locustfile_even_low_60_120_40_120s_2_requests.csv':
#   Corresponding log timestamp: 12:03:12
#   Sum of last values: 3617.5
# For CSV file 'locustfile_even_low_60_120_40_120s_3_requests.csv':
#   Corresponding log timestamp: 12:05:42
#   Sum of last values: 3695.6
# For CSV file 'locustfile_even_low_60_120_40_120s_4_requests.csv':
#   Corresponding log timestamp: 12:08:12
#   Sum of last values: 3689.3999999999996
# For CSV file 'locustfile_even_low_60_120_40_120s_5_requests.csv':
#   Corresponding log timestamp: 12:10:42
#   Sum of last values: 3656.2000000000007
# For CSV file 'locustfile_even_low_60_120_40_120s_6_requests.csv':
#   Corresponding log timestamp: 12:13:12
#   Sum of last values: 3725.1000000000004
# For CSV file 'locustfile_even_low_60_120_40_120s_7_requests.csv':
#   Corresponding log timestamp: 12:15:42
#   Sum of last values: 3729.6000000000004
# For CSV file 'locustfile_even_low_60_120_40_120s_8_requests.csv':
#   Corresponding log timestamp: 12:18:12
#   Sum of last values: 3585.7
# For CSV file 'locustfile_even_low_60_120_40_120s_9_requests.csv':
#   Corresponding log timestamp: 12:20:42
#   Sum of last values: 3567.2999999999993
# For CSV file 'locustfile_even_low_60_120_40_120s_10_requests.csv':
#   Corresponding log timestamp: 12:23:22
#   Sum of last values: 3647.5

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sums = [sum_last_values for _, _, _, sum_last_values in results_coarse if sum_last_values is not None]
grouped_sums = [sums[i:i+10] for i in range(0, len(sums), 10)]
plt.figure(figsize=(12, 6))
sns.boxplot(data=grouped_sums)
x_labels = ["burst_high","burst_med","burst_low","even_high","even_med","even_low"]
plt.xticks(range(6), x_labels)
plt.title('Boxplots of the energy consumption for the coarse-grained system')
plt.xlabel('Groups of different request frequencies and distribution')
plt.ylabel('Energy consumption (J)')
plt.show()

sums = [sum_last_values for _, _, _, sum_last_values in results_med if sum_last_values is not None]
grouped_sums = [sums[i:i+10] for i in range(0, len(sums), 10)]
plt.figure(figsize=(12, 6))
sns.boxplot(data=grouped_sums)
x_labels = ["burst_high","burst_med","burst_low","even_high","even_med","even_low"]
plt.xticks(range(6), x_labels)
plt.title('Boxplots of the energy consumption for the med-grained system')
plt.xlabel('Groups of different request frequencies and distribution')
plt.ylabel('Energy consumption (J)')
plt.show()

sums = [sum_last_values for _, _, _, sum_last_values in results_fine if sum_last_values is not None]
grouped_sums = [sums[i:i+10] for i in range(0, len(sums), 10)]
plt.figure(figsize=(12, 6))
sns.boxplot(data=grouped_sums)
x_labels = ["burst_high","burst_med","burst_low","even_high","even_med","even_low"]
plt.xticks(range(6), x_labels)
plt.title('Boxplots of the energy consumption for the fine-grained system')
plt.xlabel('Groups of different request frequencies and distribution')
plt.ylabel('Energy consumption (J)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with 3 subplots in one row
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(24, 6))

# Define x-labels
x_labels = ["burst_high", "burst_med", "burst_low", "even_high", "even_med", "even_low"]

# Coarse-grained system
sums_coarse = [sum_last_values for _, _, _, sum_last_values in results_coarse if sum_last_values is not None]
grouped_sums_coarse = [sums_coarse[i:i+10] for i in range(0, len(sums_coarse), 10)]
sns.boxplot(data=grouped_sums_coarse, ax=ax1)
ax1.set_xticklabels(x_labels)
ax1.set_title('Coarse-grained system')
ax1.set_xlabel('Request frequencies and distribution')
ax1.set_ylabel('Energy consumption (J)')

# Medium-grained system
sums_med = [sum_last_values for _, _, _, sum_last_values in results_med if sum_last_values is not None]
grouped_sums_med = [sums_med[i:i+10] for i in range(0, len(sums_med), 10)]
sns.boxplot(data=grouped_sums_med, ax=ax2)
ax2.set_xticklabels(x_labels)
ax2.set_title('Medium-grained system')
ax2.set_xlabel('Request frequencies and distribution')
ax2.set_ylabel('Energy consumption (J)')

# Fine-grained system
sums_fine = [sum_last_values for _, _, _, sum_last_values in results_fine if sum_last_values is not None]
grouped_sums_fine = [sums_fine[i:i+10] for i in range(0, len(sums_fine), 10)]
sns.boxplot(data=grouped_sums_fine, ax=ax3)
ax3.set_xticklabels(x_labels)
ax3.set_title('Fine-grained system')
ax3.set_xlabel('Request frequencies and distribution')
ax3.set_ylabel('Energy consumption (J)')

fig.suptitle('Energy consumption for different granularity levels', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/n3/t4x6rcxd63361_hz54mh10qh0000gn/T/ipykernel_97173/2170140753.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(x_labels)
# /var/folders/n3/t4x6rcxd63361_hz54mh10qh0000gn/T/ipykernel_97173/2170140753.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(x_labels)
# /var/folders/n3/t4x6rcxd63361_hz54mh10qh0000gn/T/ipykernel_97173/2170140753.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax3.set_xticklabels(x_labels)

# %%
def find_outliers_3sigma(data):
    mean = np.mean(data)
    std = np.std(data)
    outliers = [x for x in data if (x < mean - 3*std) or (x > mean + 3*std)]
    return outliers
x_labels = ["burst_high", "burst_med", "burst_low", "even_high", "even_med", "even_low"]
def print_outliers(data, system_name):
    print(f"\nOutliers for {system_name}:")
    for i, group in enumerate(data):
        outliers = find_outliers_3sigma(group)
        if outliers:
            print(f"  {x_labels[i]}: {outliers}")
        else:
            print(f"  {x_labels[i]}: No outliers")

# Coarse-grained system
sums_coarse = [sum_last_values for _, _, _, sum_last_values in results_coarse if sum_last_values is not None]
grouped_sums_coarse = [sums_coarse[i:i+10] for i in range(0, len(sums_coarse), 10)]
print_outliers(grouped_sums_coarse, "Coarse-grained system")

# Medium-grained system
sums_med = [sum_last_values for _, _, _, sum_last_values in results_med if sum_last_values is not None]
grouped_sums_med = [sums_med[i:i+10] for i in range(0, len(sums_med), 10)]
print_outliers(grouped_sums_med, "Medium-grained system")

# Fine-grained system
sums_fine = [sum_last_values for _, _, _, sum_last_values in results_fine if sum_last_values is not None]
grouped_sums_fine = [sums_fine[i:i+10] for i in range(0, len(sums_fine), 10)]
print_outliers(grouped_sums_fine, "Fine-grained system")
# Out:
# Outliers for Coarse-grained system:
#   burst_high: No outliers
#   burst_med: No outliers
#   burst_low: No outliers
#   even_high: No outliers
#   even_med: No outliers
#   even_low: No outliers
#
# Outliers for Medium-grained system:
#   burst_high: No outliers
#   burst_med: No outliers
#   burst_low: No outliers
#   even_high: No outliers
#   even_med: No outliers
#   even_low: No outliers
#
# Outliers for Fine-grained system:
#   burst_high: No outliers
#   burst_med: No outliers
#   burst_low: No outliers
#   even_high: No outliers
#   even_med: No outliers
#   even_low: No outliers

# %%
def calculate_stats(data):
    return {
        "min": np.min(data),
        "max": np.max(data),
        "avg": np.mean(data),
        "std": np.std(data),
        "med": np.median(data),
        "q1": np.percentile(data, 25),
        "q3": np.percentile(data, 75)
    }

def find_outliers_3sigma(data):
    mean, std = np.mean(data), np.std(data)
    return [x for x in data if abs(x - mean) > 3 * std]

def analyze_system(results, name):
    sums = [sum_last_values for _, _, _, sum_last_values in results if sum_last_values is not None]
    stats = calculate_stats(sums)
    outliers = find_outliers_3sigma(sums)

    print(f"\n{name} system:")
    for stat, value in stats.items():
        print(f"  {stat}: {value:.2f}")
    print(f"  Outliers: {outliers if outliers else 'None'}")

# Analyze each system
analyze_system(results_coarse, "Coarse-grained")
analyze_system(results_med, "Medium-grained")
analyze_system(results_fine, "Fine-grained")3
# Out:
# Coarse-grained system:
#   min: 3303.00
#   max: 3956.80
#   avg: 3484.03
#   std: 184.17
#   med: 3394.55
#   q1: 3358.62
#   q3: 3628.70
#   Outliers: None
#
# Medium-grained system:
#   min: 3403.10
#   max: 4208.30
#   avg: 3639.51
#   std: 210.42
#   med: 3532.60
#   q1: 3492.77
#   q3: 3821.75
#   Outliers: None
#
# Fine-grained system:
#   min: 3567.30
#   max: 4318.20
#   avg: 3828.61
#   std: 214.14
#   med: 3727.00
#   q1: 3678.90
#   q3: 3999.00
#   Outliers: None

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

sums_coarse = [sum_last_values for *_, sum_last_values in results_coarse if sum_last_values is not None]
sums_med = [sum_last_values for *_, sum_last_values in results_med if sum_last_values is not None]
sums_fine = [sum_last_values for *_, sum_last_values in results_fine if sum_last_values is not None]
sums = sums_coarse + sums_med + sums_fine

def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

groups = list(chunks(sums, 10))
statistics = []
for group in groups:
    min_val = np.min(group)
    max_val = np.max(group)
    avg_val = np.mean(group)
    statistics.append((min_val, max_val, avg_val))

x_labels = ["coarse_burst_high","coarse_burst_med","coarse_burst_low","coarse_even_high","coarse_even_med","coarse_even_low",
            "med_burst_high","med_burst_med","med_burst_low","med_even_high","med_even_med","med_even_low",
            "fine_burst_high","fine_burst_med","fine_burst_low","fine_even_high","fine_even_med","fine_even_low"]

for i, (min_val, max_val, avg_val) in enumerate(statistics):
    print(f"{x_labels[i]}: Min = {min_val:.2f}, Max = {max_val:.2f}, Average = {avg_val:.2f}")

averages = [stat[2] for stat in statistics]
bar_positions = np.arange(1, len(averages) + 1) * 1.7

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b'] * 3
pdf_filename = 'train_ticket_energy_consumption.pdf'
with PdfPages(pdf_filename) as pdf:
    plt.figure(figsize=(15, 8), dpi=300)
    bars = plt.bar(bar_positions, averages, width=0.6, color=colors)
    plt.xlabel('Group', fontsize=12)
    plt.ylabel('Average Energy Consumption (J)', fontsize=12)
    plt.title('Average Energy Consumption for Train-Ticket System', fontsize=14)
    plt.xticks(bar_positions, x_labels, rotation=45, ha='right', fontsize=8)
    plt.ylim(min(averages) - 150, max(averages) + 30)

    line_positions = [3205.9, 3403.6, 3602.1]
    line_labels = ['coarse', 'med', 'fine']
    line_colors = ['red', 'green', 'blue']
    for y, label, color in zip(line_positions, line_labels, line_colors):
        plt.axhline(y=y, color=color, linestyle='--')
        plt.text(bar_positions[-1] + 0.5, y, label, color=color, va='center', fontsize=10)

    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval:.2f}', ha='center', va='bottom', fontsize=8, rotation=90)

    plt.tight_layout()
    pdf.savefig(bbox_inches='tight')
    plt.close()

print(f"PDF saved as {pdf_filename}")
# Out:
# coarse_burst_high: Min = 3524.30, Max = 3956.80, Average = 3683.56
# coarse_burst_med: Min = 3338.10, Max = 3412.60, Average = 3382.50
# coarse_burst_low: Min = 3307.30, Max = 3399.00, Average = 3346.23
# coarse_even_high: Min = 3681.20, Max = 3928.00, Average = 3761.65
# coarse_even_med: Min = 3332.70, Max = 3424.20, Average = 3387.27
# coarse_even_low: Min = 3303.00, Max = 3403.00, Average = 3342.99
# med_burst_high: Min = 3774.70, Max = 4208.30, Average = 3937.53
# med_burst_med: Min = 3468.00, Max = 3578.20, Average = 3529.61
# med_burst_low: Min = 3449.20, Max = 3539.10, Average = 3495.82
# med_even_high: Min = 3753.00, Max = 4178.40, Average = 3889.62
# med_even_med: Min = 3464.50, Max = 3569.20, Average = 3522.11
# med_even_low: Min = 3403.10, Max = 3535.20, Average = 3462.38
# fine_burst_high: Min = 3640.30, Max = 4318.20, Average = 4151.79
# fine_burst_med: Min = 3639.40, Max = 3873.90, Average = 3730.59
# fine_burst_low: Min = 3655.30, Max = 3804.90, Average = 3698.49
# fine_even_high: Min = 3904.90, Max = 4229.20, Average = 4031.92
# fine_even_med: Min = 3616.50, Max = 3750.20, Average = 3702.50
# fine_even_low: Min = 3567.30, Max = 3729.60, Average = 3656.36
# PDF saved as train_ticket_energy_consumption.pdf
